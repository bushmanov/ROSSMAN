# %%
f1 = pd.read_csv('xgb_test_feature_1.csv')
f1_1 = pd.read_csv('xgb_test_feature_1_1.csv')
f2 = pd.read_csv('xgb_test_feature_2.csv')
f2_1 = pd.read_csv('xgb_test_feature_2_1.csv')
f3 = pd.read_csv('xgb_test_feature_3.csv')
f3_1 = pd.read_csv('xgb_test_feature_3_1.csv')

# %%
plt.figure(figsize=(15,10))
plt.subplot(231)
plt.scatter(x=f1.xgb_test, y=f2.xgb_test)
plt.xlabel("F1")
plt.ylabel("F2")
plt.title("F2 x F1")
plt.subplot(232)
plt.scatter(x=f1.xgb_test, y=f3.xgb_test)
plt.xlabel("F1")
plt.ylabel("F3")
plt.title("F3 x F1")
plt.subplot(233)
plt.scatter(x=f2.xgb_test, y=f3.xgb_test)
plt.xlabel("F2")
plt.ylabel("F3")
plt.title("F3 x F2")
plt.subplot(234)
plt.scatter(x=f1.xgb_test, y=f1_1.xgb_test_1)
plt.xlabel("F1")
plt.ylabel("F1_1")
plt.title("F1_1 x F1")
plt.subplot(235)
plt.scatter(x=f2.xgb_test, y=f2_1.xgb_test_1)
plt.xlabel("F2")
plt.ylabel("F2_1")
plt.title("F2_1 x F2")
plt.subplot(236)
plt.scatter(x=f3.xgb_test, y=f3_1.xgb_test_1)
plt.xlabel("F3")
plt.ylabel("F3_1")
plt.title("F3_1 x F3");

# %%
f4 = pd.DataFrame({'Id':f3.id,'Sales':np.sqrt(f3.xgb_test*f2.xgb_test)})
# f4.to_csv('feature4', index=False)

# %%
f5 = pd.read_csv('sub777.csv')

# %%
plt.scatter(x=f5.sort_values('Id').Sales, y=f2.sort_values('id').xgb_test);

# %%
f2 = f2.sort_values('id')

# %%
f5 = f5.sort_values('Id')

# %%
f6 = pd.DataFrame({'Id':f2['id'], 'Sales':np.sqrt(f5.Sales.values*f2.xgb_test.values)})

# %%
plt.scatter(x=f5.Sales,y=f6.Sales);
