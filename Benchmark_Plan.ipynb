# %% [markdown]
# # benchmark1_kaggle.ipynb
#
# ### out
# benchmark1_train.csv
# benchmark1_test.csv
#
# # benchmark1_kaggle.R
#
# ### feature.names
#  [1] "Store"                     "DayOfWeek"                 "Open"                      "Promo"                     "SchoolHoliday"
#  [6] "StoreType"                 "Assortment"                "CompetitionDistance"       "CompetitionOpenSinceMonth" "CompetitionOpenSinceYear"
# [11] "Promo2"                    "Promo2SinceWeek"           "Promo2SinceYear"           "PromoInterval"             "month"
# [16] "year"                      "day"
#
# ### out
# `benchmark1_kaggle.RDS`
#
# # benchmark2_mine_prepro_grouped.ipynb
#
# ### out
#
# benchmark2_train.csv
# benchmark2_test.csv
#
# # benchmark2_mine_prepro_grouped.R
#
# ### feature.names
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "Year"                "Month"               "Day"
#
#
# ### out
# `benchmark2_mine_prepro_grouped.RDS`
#
#
#
# # benchmark3_mine_prepro_OHE.ipynb
#
# ### out
#
# benchmark3_train.csv
# benchmark3_test.csv
#
# # benchmark3_mine_prepro_OHE.R
#
# ### feature.names
#
# [1] "Promo"               "Store"               "CompetitionDistance" "Promo2"
#  [5] "competition"         "Promo2_R"            "Day"                 "DayOfWeek_1"
#  [9] "DayOfWeek_2"         "DayOfWeek_3"         "DayOfWeek_4"         "DayOfWeek_5"
# [13] "DayOfWeek_6"         "DayOfWeek_7"         "Year_2013"           "Year_2014"
# [17] "Year_2015"           "Month_1"             "Month_2"             "Month_3"
# [21] "Month_4"             "Month_5"             "Month_6"             "Month_7"
# [25] "Month_8"             "Month_9"             "Month_10"            "Month_11"
# [29] "Month_12"            "StateHoliday_0"      "StateHoliday_1"      "StateHoliday_2"
# [33] "StateHoliday_3"      "SchoolHoliday_0"     "SchoolHoliday_1"     "StoreType_0"
# [37] "StoreType_1"         "StoreType_2"         "StoreType_3"         "Assortment_0"
# [41] "Assortment_1"        "Assortment_2"
#
# `benchmark3_mine_prepro_OHE.RDS`
#
#
# # benchmark4_mine_prepro_grouped.ipynb
#
# ### out
#
# benchmark4_train.csv
# benchmark4_test.csv
#
# # benchmark4_mine_prepro_grouped.R
#
# ### feature.names  (15)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "Year"                "Month"               "WoY"                 "Day"
#
#
# ### out
#
# `benchmark4_mine_prepro_grouped.RDS`
#
# # benchmark5_mine_prepro_grouped.ipynb ( same for benchmark4 & benchmark5)
# Benchmark4 w/o Promo2 feature
#
# ### out
# benchmark4_train.csv  (same as benchmark4)
# benchmark4_test.csv  (same as benchmark4)
#
# # benchmark5_mine_prepro_grouped.R
#
# ### feature.names  (14)
#
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "competition"         "Promo2_R"
# [11] "Year"                "Month"               "WoY"                 "Day"
#
#
# ### out
# `benchmark5_mine_prepro_grouped.RDS`
#
#
#
# # benchmark6_mine_prepro_grouped.ipynb
#
# Built upon `benchmark4_mine_prepro_grouped.ipynb` by adding to `StateHoliday` 2 more variables:
# - `t` -- tomorrow is a holiday
# - `y` -- yesterday was a holiday
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark6_mine_prepro_grouped.R
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark6_mine_prepro_grouped.RDS`
#
#
# # benchmark7_mine_prepro_grouped.ipynb
#
# Built upon `benchmark6_mine_prepro_grouped.ipynb` by adding to `Day_of_Year = 'Day*WoY'`:
#
#
# ### out
#
# benchmark7_train.csv
# benchmark7_test.csv
#
# # benchmark7_mine_prepro_grouped.R
#
# ### feature.names  (18)
#
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"                 "Day_of_Year"
#
# ### out
# `benchmark7_mine_prepro_grouped.RDS`
# `'fill_benchmark7.csv'`  -- prdictions with input data.frame
#
#
# # benchmark8_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb`
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark8_mine_prepro_grouped.R
#
# This is alpha tuning in the range [0.0001, 0.0005,.001, 0.05, 0.1, 0.3, 0.5]
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark8_mine_prepro_grouped.RDS`
#
# # benchmark9_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb`
# (same as benchmark8, but for lambda tuning)
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark9_mine_prepro_grouped.R
#
# This is lambda tuning in the range [0.5, 1., 1.5,2,3]
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark9_mine_prepro_grouped.RDS`
#
#
# # benchmark10_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb` but with eta=.02
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark10_mine_prepro_grouped.R
#
# This is lambda tuning in the range [0.5, 1., 1.5,2,3]
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark10_mine_prepro_grouped.RDS`
#
# # benchmark11_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb`
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark11_mine_prepro_grouped.R
#
# This is `colsample_bytree` tuning in the range [0.3,.5]
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark11_mine_prepro_grouped.RDS`
#
# # benchmark12_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb`
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark12_mine_prepro_grouped.R
#
# This is `subsample` tuning in the range [0.3,.5]
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark12_mine_prepro_grouped.RDS`
#
# # benchmark13_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb`, but tuning on 10'000 subsample (early stopping?)
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark13_mine_prepro_grouped.R
#
#
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark12_mine_prepro_grouped.RDS`
#
# # benchmark14_mine_prepro_grouped.ipynb
#
# Same as `benchmark6_mine_prepro_grouped.ipynb`, but:
#
#
# - removed 100 outliers (vs 30 in benchmark6)
# - tuning on 10'000 subsample (during Aug/Sep 2014)
#
# ### out
#
# benchmark6_train.csv
# benchmark6_test.csv
#
# # benchmark14_mine_prepro_grouped.R
#
#
#
# ### feature.names  (17)
#  [1] "DayOfWeek"           "Promo"               "SchoolHoliday"       "StateHoliday"        "Store"
#  [6] "StoreType"           "Assortment"          "CompetitionDistance" "Promo2"              "competition"
# [11] "Promo2_R"            "YwH"                 "TwH"                 "Year"                "Month"
# [16] "WoY"                 "Day"
#
# ### out
# `benchmark12_mine_prepro_grouped.RDS`
